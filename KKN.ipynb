# %% [markdown]
# Assignment No.1:k-nearest neighbors

# %% [markdown]
# Before running this block, make sure to upload "data.mat" in the google drive.

# %%
#Enter your path of dataset from google drive  
import scipy.io as sio
GOOGLE_COLAB = True
path = "https://drive.google.com/drive/u/2/folders/1B3er5zYNt08_N63DmxAgDZQVNF3XgM5w"
if GOOGLE_COLAB:
    from google.colab import drive, files
    drive.mount('/content/drive/')
    path = "/content/drive/My Drive/SE-807 Machine Learning Assignment # 1 - Dr Wajahat Hussain/"

dataset = path + "data.mat" 

#Enter path of your test image
test_image=path+"ShujaHameed.jpg"
mat_contents = sio.loadmat(dataset)
mat_contents
images = mat_contents['images']
label = mat_contents['C']
images.shape
# Out:
# Mounted at /content/drive/
# (50, 3072)

# %% [markdown]
# If you can see the shape of images in 'data.mat' then your data has been read.
#
# 1.   List item
# 2.   List item

# %%
import numpy as np 
images= np.transpose(images)
images.shape
im = np.reshape(images, [ 32, 32, 3, -1], order="F")

# %%
from matplotlib import pyplot as plt
#import cv2

#plt.imshow(im[:,:,:,41])
#print(im[:,:,:,0].shape)
a= im[:,:,:,11]
plt.imshow(a)
a.shape
# Out:
# (32, 32, 3)

# %%
b= im[:,:,:,39]
plt.imshow(b)
b.shape
# Out:
# (32, 32, 3)

# %% [markdown]
# You Need to write your code in this block.

# %%
from scipy import misc
import cv2
from math import sqrt
from numpy import ndarray
from matplotlib import pyplot as plt
from PIL import Image
import matplotlib.image as mpimg

d = Image.open('/content/drive/My Drive/SE-807 Machine Learning Assignment # 1 - Dr Wajahat Hussain/ShujaHameed.jpg')
resized = d.resize((32, 32))
resized.save('ShujaHameedNew.jpg')

e= plt.imread("/content/ShujaHameedNew.jpg")
imgplot = plt.imshow(e)
plt.figure()

global distance 
myarray = []
for i in range(50):
    G = im[:,:,:,i]
    f = G
    distance = np.linalg.norm(e-f)
    #print(distance)
    myarray.insert(i,distance) 
    G = np.reshape(G,[-1], order="F")
    images.shape

oldarray = np.copy(myarray)
print(oldarray)
myarray.sort()
newarray = np.copy(myarray)
print(newarray)
print("The least five distances are: ")
print(newarray[0])
print(newarray[1])
print(newarray[2])
print(newarray[3])
print(newarray[4])

#check the index of each of the above distances in the dataset(old array)
for j in range(50):
  check = oldarray[j]
  if newarray[0] == check:
    c1 = j
    print (j) 

for k in range(50):
  check1 = oldarray[k]
  if newarray[1] == check1:
    c2 = k
    print (k)

for l in range(50):
  check2 = oldarray[l]
  if newarray[2] == check2:
    c3 = l
    print (l)    

for m in range(50):
  check3 = oldarray[m]
  if newarray[3] == check3:
    c4 = m
    print (m)

for n in range(50):
  check4 = oldarray[n]
  if newarray[4] == check4:
    c5 = n
    print (n)

#declare the 10 classes(arrays) by the names of the celebrities
morgan = []
ahsan_khan = []
tom_cruise = []
sanam_baloch = []
meryl_streep = []
bilawal_bhutto = []
viola_davis = []
aishwarya_rai = []
fawad_khan = []
mahira_khan = []

#fill the 10 classes(arrays) by their respective indices as per the given dataset
for i in range(5):
  morgan.insert(i,i) 
for i in range(5,10,1):
  ahsan_khan.insert(i,i)
for i in range(10,15,1):
  tom_cruise.insert(i,i)
for i in range(15,20,1):
  sanam_baloch.insert(i,i)
for i in range(20,25,1):
  meryl_streep.insert(i,i)
for i in range(25,30,1):
  bilawal_bhutto.insert(i,i)
for i in range(30,35,1):
  viola_davis.insert(i,i)
for i in range(35,40,1):
  aishwarya_rai.insert(i,i)
for i in range(40,45,1):
  fawad_khan.insert(i,i)
for i in range(45,50,1):
  mahira_khan.insert(i,i)

#print the created arrays(just a check, not mandatory)
print(morgan)
print(ahsan_khan)
print(tom_cruise)
print(sanam_baloch)
print(meryl_streep)
print(bilawal_bhutto)
print(viola_davis)
print(aishwarya_rai)
print(fawad_khan)
print(mahira_khan)

#take user input, the value of k
print("Enter the value of 'k' for k-NN Algorithm: ")
k_val = input()
k_val = int(k_val)
print("Implementing k-NN algorithm for k = ", k_val)
index_array = [c1,c2,c3,c4,c5]

#implement according to the value of k given by the user
if k_val == 1:
  index_array = [c1]
if k_val == 3:
  index_array = [c1,c2,c3] #pick the three least distance indices
if k_val == 5:
  index_array = [c1,c2,c3,c4,c5] #pick the least five distance indices

print(index_array) #just a check
new = np.array(index_array)
morgan_count = ahsan_count = tom_count = sanam_count = meryl_count = bilawal_count = viola_count = aishwarya_count = fawad_count = mahira_count = 0

for i in range(k_val):
  if index_array[i] in morgan:
    morgan_count = morgan_count+1
  if index_array[i] in ahsan_khan:
    ahsan_count = ahsan_count+1
  if index_array[i] in tom_cruise:
    tom_count = tom_count+1
  if index_array[i] in sanam_baloch:
    sanam_count = sanam_count+1
  if index_array[i] in meryl_streep:
    meryl_count = meryl_count+1
  if index_array[i] in bilawal_bhutto:
    bilawal_count = bilawal_count+1
  if index_array[i] in viola_davis:
    viola_count = viola_count+1
  if index_array[i] in aishwarya_rai:
    aishwarya_count = aishwarya_count+1
  if index_array[i] in fawad_khan:
    fawad_count = fawad_count+1
  if index_array[i] in mahira_khan:
    mahira_count = mahira_count+1

#print(viola_count)
count_array = [morgan_count,ahsan_count,tom_count,sanam_count,meryl_count,bilawal_count,viola_count,aishwarya_count,fawad_count,mahira_count]
minpos = count_array.index(max(count_array)) #return the index of the max value in the count_array, i.e, the class having most votes
print(minpos)
global index

if minpos == 0:
  character = "Morgan"
  index = 0
if minpos == 1:
  character = "Ahsan Khan"
  index = 5
if minpos == 2:
  character = "Tom Cruise"
  index = 10
if minpos == 3:
  character = "Sanam Baloch"
  index = 15
if minpos == 4:
  character = "Meryl Streep"
  index = 20
if minpos == 5:
  character = "Bilawal Bhutto"
  index = 25
if minpos == 6:
  character = "Viola Davis"
  index = 30
if minpos == 7:
  character = "Aishwarya Rai"
  index = 35
if minpos == 8:
  character = "Fawad Khan"
  index = 40
if minpos == 9:
  character = "Mahira Khan"
  inedx = 45


if k_val == 1:
  print("As per 1-NN algorithm, your face resembles to ", character)
  result = im[:,:,:,c1] #result of 1-NN algorithm
  plt.imshow(result)
  result.shape

if k_val == 3:
  a  = max(count_array)
  if a > 1:
    print ("As per 3-NN algorithm, your face resembles to ", character) 
    result1 = im[:,:,:,index] #result of 3-NN algorithm
    imgplot = plt.imshow(index)
    plt.figure()    
  else:
    result1 = im[:,:,:,c1] #result of 3-NN algorithm
    imgplot = plt.imshow(result1)
    plt.figure()
        #plt.imshow(result1)
    result2 = im[:,:,:,c2] #result of 3-NN algorithm
    imgplot = plt.imshow(result2)
    plt.figure()
        #plt.imshow(result2)
    result3 = im[:,:,:,c3] #result of 3-NN algorithm
    imgplot = plt.imshow(result3)
    plt.figure()
  
if k_val == 5:
  print ("As per 5-NN algorithm, your face resembles to ", character)
  result1 = im[:,:,:,c1] #result of 5-NN algorithm
  imgplot = plt.imshow(result1)
  plt.figure()
  #plt.imshow(result1)
  result2 = im[:,:,:,c2] #result of 5-NN algorithm
  imgplot = plt.imshow(result2)
  plt.figure()
  #plt.imshow(result2)
  result3 = im[:,:,:,c3] #result of 5-NN algorithm
  imgplot = plt.imshow(result3)
  plt.figure()
    #plt.imshow(result3)
  result4 = im[:,:,:,c4] #result of 5-NN algorithm
  imgplot = plt.imshow(result4)
  plt.figure()
    #plt.imshow(result4)
  result5 = im[:,:,:,c5] #result of 5-NN algorithm
  imgplot = plt.imshow(result5)
  plt.figure()
  a  = max(count_array)
  if a > 1:
    print ("As per 5-NN algorithm, your face resembles to ", character)
    result1 = im[:,:,:,index] #result of 5-NN algorithm
    imgplot = plt.imshow(result1)
    plt.figure()
  else: 
    result1 = im[:,:,:,c1] #result of 5-NN algorithm
    imgplot = plt.imshow(result1)
    plt.figure()
    #plt.imshow(result1)
    result2 = im[:,:,:,c2] #result of 5-NN algorithm
    imgplot = plt.imshow(result2)
    plt.figure()
    #plt.imshow(result2)
    result3 = im[:,:,:,c3] #result of 5-NN algorithm
    imgplot = plt.imshow(result3)
    plt.figure()
    #plt.imshow(result3)
    result4 = im[:,:,:,c4] #result of 5-NN algorithm
    imgplot = plt.imshow(result4)
    plt.figure()
    #plt.imshow(result4)
    result5 = im[:,:,:,c5] #result of 5-NN algorithm
    imgplot = plt.imshow(result5)
    plt.figure()
    #plt.imshow(result5)
  


    #Read your image here
####### Your code here #######
#c= plt.imread("/content/drive/My Drive/SE-807 Machine Learning Assignment # 1 - Dr Wajahat Hussain/ShujaHameed.jpg")
#plt.imooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    (c)
#c.shape




############################
   

    #Resize your image
####### Your code here #######
#pil_im = Image.open('/content/drive/My Drive/SE-807 Machine Learning Assignment # 1 - Dr Wajahat Hussain/ShujaHameed.jpg')
#print(pil_im.format)
#rint(pil_im.mode)
#print(pil_im.size)
#il_im.show()

##############################
   
   
    #Reshape your image as we reshape the image of dataset
####### Your code here #######
#d = Image.open('/content/drive/My Drive/SE-807 Machine Learning Assignment # 1 - Dr Wajahat Hussain/ShujaHameed.jpg')
#resized = d.resize((32, 32))
#resized.save('ShujaHameedNew.jpg')

#e= plt.imread("/content/ShujaHameedNew.jpg")
#plt.imshow(e)
#e.shape


#############################
    #Calculate Eucleadian distance between your image and dataset 
####### Your code here #######

##############################
# Out:
# [9755.37144347 8331.3624336  8616.29119749 8724.01232232 7803.73865529
#  8067.86644659 8250.41750459 8175.64480637 7960.3802673  7676.92171381
#  8729.40593626 7843.36311795 7704.70856035 8295.3956506  7390.68373021
#  7952.1770604  8264.24225202 8506.12203063 9676.97344215 7772.3173507
#  7860.45068682 8242.14450249 8014.44970038 8349.86323241 9006.96547123
#  9495.4888763  8860.69263658 9202.5704018  8226.32554668 8848.9213467
#  8724.78486841 7550.15430306 8013.12223793 7701.90969825 7479.49623972
#  9279.90835084 8616.05501375 7922.30856506 8367.76917703 7271.36204572
#  8231.01682661 8005.46350938 8300.29535619 7115.52647385 8615.44943691
#  8122.09412652 8375.77059141 8249.85527146 8587.14242341 7700.8686523 ]
# [7115.52647385 7271.36204572 7390.68373021 7479.49623972 7550.15430306
#  7676.92171381 7700.8686523  7701.90969825 7704.70856035 7772.3173507
#  7803.73865529 7843.36311795 7860.45068682 7922.30856506 7952.1770604
# ...

# %%
a = np.array([[1,2,3],
              [4,5,6]])
print(a[:,:])
np.array(1)
print(range(50))
# Out:
# [[1 2 3]
#  [4 5 6]]
# range(0, 50)

# %% [markdown]
# # New Section

# %% [markdown]
# In this Block you need to fill the code for 1-NN.

# %%
# Write code for 1 NN
#Find min distance
#Fine at which point min value exists

####### Your code here #######




##############################

# %% [markdown]
# Write code for 3 NN

# %%
#3 NN
#Write code for 3 NN
#Find 3 min distances
#Find their instances
#hint: Use for Loop

####### Your code here #######





##############################

# %% [markdown]
# Write code for 5 NN

# %%
#Write code for 5 NN
#Find 5 min distances
#Find their instances

####### Your code here #######





##############################
